# %% [markdown]
# <a href="https://colab.research.google.com/github/HemaRavi94/Machine-Learning/blob/main/decision_trees_assignment15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Social_Network_Ads.csv

# %% [markdown]
# **Importing the libraries**

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import tree
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %% [markdown]
# **Importing the dataset**

# %%
data=pd.read_csv('Social_Network_Ads.csv')

# %% [markdown]
# **Splitting the dataset into the Training set and Test set**

# %%
data.columns
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
x=data[['User ID', 'Gender', 'Age', 'EstimatedSalary']]
y=data['Purchased']

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.03, random_state=0)

x_train, x_test, y_train, y_test
# Out:
# (      User ID  Gender  Age  EstimatedSalary
#  113  15773447    Male   37            55000
#  348  15579212    Male   39            77000
#  12   15746139    Male   20            86000
#  59   15789109  Female   32           117000
#  293  15760570    Male   37            77000
#  ..        ...     ...  ...              ...
#  323  15619465  Female   48            30000
#  192  15779581    Male   29            43000
#  117  15591433    Male   36            52000
#  47   15776348  Female   27            54000
#  172  15794661  Female   26           118000
#
#  [388 rows x 4 columns],       User ID  Gender  Age  EstimatedSalary
#  132  15725660    Male   30            87000
#  309  15652400  Female   38            50000
#  341  15776844    Male   35            75000
#  196  15738448  Female   30            79000
#  246  15638003  Female   35            50000
#  60   15814004    Male   27            20000
#  155  15610140  Female   31            15000
# ...

# %% [markdown]
# **Feature Scaling**

# %%
x=data[['User ID', 'Age', 'EstimatedSalary']]
y=data['Purchased']
x.shape,y.shape
# Out:
# ((400, 3), (400,))

# %%
scaler= StandardScaler()

standardization = scaler.fit_transform(x)

# %%
standardization
# Out:
# array([[-0.93657932, -1.78179743, -1.49004624],
#        [ 1.66838653, -0.25358736, -1.46068138],
#        [-0.32087714, -1.11320552, -0.78528968],
#        ...,
#        [-0.52039175,  1.17910958, -1.46068138],
#        [ 0.88695546, -0.15807423, -1.07893824],
#        [-1.36231017,  1.08359645, -0.99084367]])

# %% [markdown]
# **Fitting Decision Tree Classification to the Training set**

# %%
x=data[['User ID', 'Age', 'EstimatedSalary']]
y=data[['Purchased']]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
obj=DecisionTreeClassifier(max_depth=9)
dtree=obj.fit(x_train,y_train)

# %% [markdown]
# **Predicting the Test set results**

# %%
predicted=obj.predict(x_test)
print(classification_report(y_test,predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.93      0.86        71
#            1       0.86      0.65      0.74        49
#
#     accuracy                           0.82       120
#    macro avg       0.83      0.79      0.80       120
# weighted avg       0.82      0.82      0.81       120

# %%
print('Testing accuracy:',accuracy_score(y_test,predicted))
# Out:
# Testing accuracy: 0.8166666666666667

# %% [markdown]
# **Making the Confusion Matrix**

# %%
confusion_matrix(y_test,predicted)
# Out:
# array([[66,  5],
#        [17, 32]])

# %% [markdown]
# **Visualising the Training set results**

# %%
X=data[['User ID', 'Age', 'EstimatedSalary']]
y=data[['Purchased']]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)
obj=DecisionTreeClassifier(max_depth=9)
dtree=obj.fit(x_train,y_train)
predict=obj.predict(x_train)
plt.figure(figsize=(20,10))
tree.plot_tree(dtree,class_names=x.columns,rounded=True,filled=True,fontsize=4)
print(obj.get_depth())
plt.show()
# Out:
# 9

# %% [markdown]
# **Visualising the Test set results**

# %%
X=data[['User ID', 'Age', 'EstimatedSalary']]
y=data[['Purchased']]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)
obj=DecisionTreeClassifier(max_depth=9)
dtree=obj.fit(x_test,y_test)
predict=obj.predict(x_test)
plt.figure(figsize=(20,10))
tree.plot_tree(dtree,class_names=x.columns,rounded=True,filled=True,fontsize=4)
print(obj.get_depth())
plt.show()
# Out:
# 9
